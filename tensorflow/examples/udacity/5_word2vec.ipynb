# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.310261
# Nearest to into: legionnaire, statehouse, baton, typhoons, pierre, marches, hannover, melchizedek,
# Nearest to american: cornerback, ra, aleksei, aleutian, council, retract, glycogen, savvy,
# Nearest to an: mico, undernet, omaha, refrained, glaciation, whenever, juices, textrm,
# Nearest to his: helena, vipers, selassie, tilden, grounds, hopes, colliding, insects,
# Nearest to can: economically, presbyterians, corticosteroids, numismatics, heures, vaduz, voted, adolphe,
# Nearest to than: urey, pods, plotters, idols, seat, vfa, consultant, cigarette,
# Nearest to will: unequivocally, abm, reelection, pall, normalized, hezekiah, detects, firearm,
# Nearest to three: fruitless, unlimited, pike, cinematographer, croix, wernicke, jornal, rapid,
# Nearest to UNK: overpopulation, capoeiristas, rwanda, girth, theism, marvelous, xnor, edict,
# Nearest to time: chandragupta, gallbladder, lucasfilm, gonzaga, herald, supermarket, cockpits, berenguer,
# Nearest to also: kore, feldman, chapin, inviting, task, forester, braintree, descendant,
# Nearest to that: collar, designing, rider, yaw, pigs, fuerza, perish, counterbalance,
# Nearest to they: bilingualism, griffin, discrepancy, po, mpls, bundaberg, goyen, denham,
# Nearest to are: odp, secretion, allegedly, patrolled, goro, oscillating, bulls, dragoon,
# Nearest to some: coffey, amounted, riviera, reed, q, elves, sidelines, msf,
# Nearest to years: dina, significance, hitter, goes, behistun, capacitors, expression, portrayal,
# Average loss at step 2000: 4.374626
# Average loss at step 4000: 3.866527
# Average loss at step 6000: 3.794276
# Average loss at step 8000: 3.691418
# Average loss at step 10000: 3.615721
# Nearest to into: baton, legionnaire, disbelief, pierre, juices, balzac, signing, wolsey,
# Nearest to american: ra, aleksei, cornerback, antoninus, teodoro, im, upgraded, english,
# Nearest to an: the, glaciation, known, this, kittiwake, isomers, suck, bsod,
# Nearest to his: their, the, its, her, my, selassie, casta, gemayel,
# Nearest to can: may, would, must, consultant, tippit, crater, narrowed, will,
# Nearest to than: harding, mcgill, guild, idols, colossians, or, pods, pessimistic,
# Nearest to will: would, detects, cctld, surrounded, pompous, can, mistresses, voluntary,
# Nearest to three: five, six, seven, four, two, eight, zero, nine,
# Nearest to UNK: riefenstahl, namath, helpdesk, subscripts, diamonds, protectorate, dop, corey,
# Nearest to time: gallbladder, manchus, matra, reversed, wound, chandragupta, seminar, eratosthenes,
# Nearest to also: which, who, kore, not, there, often, it, still,
# Nearest to that: which, martinez, it, pigs, specimens, gayle, parallel, kuhn,
# Nearest to they: he, it, we, not, there, johnston, flirt, fishes,
# Nearest to are: were, is, odp, have, roundhouse, yorker, was, sanchez,
# Nearest to some: many, czarist, mood, all, cimbri, gigabyte, bunyan, impermanent,
# Nearest to years: dina, capacitors, caesars, hala, significance, ara, jef, lyne,
# Average loss at step 12000: 3.607386
# Average loss at step 14000: 3.573463
# Average loss at step 16000: 3.409494
# Average loss at step 18000: 3.459334
# Average loss at step 20000: 3.539681
# Nearest to into: from, juices, with, legionnaire, indigo, preoccupations, dup, wolsey,
# Nearest to american: french, british, australian, aleksei, english, upgraded, laika, im,
# Nearest to an: the, glaciation, oda, isomers, coercion, bsod, kittiwake, lawrencium,
# Nearest to his: their, her, its, my, the, casta, selassie, gemayel,
# Nearest to can: may, would, will, must, could, should, consultant, unclaimed,
# Nearest to than: or, guild, mcgill, talib, idols, kills, jaya, afrika,
# Nearest to will: would, can, may, should, could, shall, to, surrounded,
# Nearest to three: five, four, two, six, seven, eight, zero, nine,
# Nearest to UNK: riefenstahl, somaliland, mycenae, baker, observation, plague, physicist, barking,
# Nearest to time: gallbladder, matra, manchus, wound, seminar, chives, reversed, borders,
# Nearest to also: which, not, often, who, kore, still, then, sometimes,
# Nearest to that: which, what, soot, specimens, pigs, unfccc, however, resh,
# Nearest to they: he, there, we, it, who, these, not, headache,
# Nearest to are: were, is, have, odp, roundhouse, was, other, meitner,
# Nearest to some: many, these, all, any, most, other, several, their,
# Nearest to years: dina, caesars, capacitors, trebizond, hala, dubuque, suspicion, jef,
# Average loss at step 22000: 3.506531
# Average loss at step 24000: 3.493788
# Average loss at step 26000: 3.483267
# Average loss at step 28000: 3.483537
# Average loss at step 30000: 3.504015
# Nearest to into: from, through, juices, preoccupations, legionnaire, indigo, wolsey, balzac,
# Nearest to american: british, english, french, australian, aleksei, italian, manageable, russian,
# Nearest to an: glaciation, coercion, lawrencium, bans, tikal, tropospheric, another, agonists,
# Nearest to his: her, their, its, my, the, s, cellini, selassie,
# Nearest to can: may, would, will, could, must, should, might, unclaimed,
# Nearest to than: guild, or, mcgill, snack, hollingworth, jaya, afrika, orford,
# Nearest to will: would, can, may, could, must, should, shall, to,
# Nearest to three: five, four, seven, six, two, eight, nine, zero,
# Nearest to UNK: riefenstahl, undergoing, exmoor, hoddle, urdu, oneworld, abd, h,
# Nearest to time: gallbladder, matra, wound, manchus, seminar, saw, beacon, borders,
# Nearest to also: still, often, kore, actually, sometimes, who, which, it,
# Nearest to that: which, what, this, however, fluctuate, deletion, specimens, batavians,
# Nearest to they: we, there, he, it, you, who, these, not,
# Nearest to are: were, is, have, other, many, these, odp, be,
# Nearest to some: many, these, all, several, other, any, various, their,
# Nearest to years: caesars, year, trebizond, jef, hala, days, dina, months,
# Average loss at step 32000: 3.499768
# Average loss at step 34000: 3.494656
# Average loss at step 36000: 3.454582
# Average loss at step 38000: 3.310962
# Average loss at step 40000: 3.431483
# Nearest to into: from, through, juices, legionnaire, doorman, elegantly, preoccupations, balzac,
# Nearest to american: british, australian, aleksei, english, french, russian, german, digimon,
# Nearest to an: glaciation, coercion, another, herbivore, concessions, fanon, heuristics, agonists,
# Nearest to his: her, their, its, my, the, your, s, deals,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to than: or, guild, disguising, afrika, floated, way, snack, orford,
# Nearest to will: would, can, may, could, must, should, might, shall,
# Nearest to three: four, two, five, seven, six, eight, nine, zero,
# Nearest to UNK: b, j, tombaugh, e, intrigued, coach, carrey, d,
# Nearest to time: seminar, manchus, wound, gallbladder, matra, saw, perpetrators, authors,
# Nearest to also: still, often, which, sometimes, now, actually, not, usually,
# Nearest to that: which, what, this, however, where, specimens, deletion, kiosks,
# Nearest to they: we, he, there, you, it, she, not, these,
# Nearest to are: were, is, have, be, include, retroflex, although, aperture,
# Nearest to some: many, these, several, any, their, different, this, most,
# Nearest to years: months, days, hala, caesars, jef, trebizond, times, forbes,
# Average loss at step 42000: 3.434580
# Average loss at step 44000: 3.451347
# Average loss at step 46000: 3.453946
# Average loss at step 48000: 3.351361
# Average loss at step 50000: 3.386333
# Nearest to into: through, from, legionnaire, doorman, juices, within, preoccupations, elegantly,
# Nearest to american: british, aleksei, australian, french, russian, english, actors, italian,
# Nearest to an: glaciation, concessions, honed, the, herbivore, unaids, another, agonists,
# Nearest to his: their, her, its, my, your, our, s, the,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to than: or, and, guild, jaya, but, hollingworth, giordano, disguising,
# Nearest to will: would, can, could, may, must, should, shall, might,
# Nearest to three: four, seven, six, five, eight, nine, two, zero,
# Nearest to UNK: e, et, undergoing, aground, http, vytautas, l, auxiliary,
# Nearest to time: year, manchus, saw, seminar, way, period, day, matra,
# Nearest to also: often, still, sometimes, now, which, actually, then, here,
# Nearest to that: which, however, what, fluctuate, this, monotheist, hamel, who,
# Nearest to they: we, he, there, you, it, she, these, who,
# Nearest to are: were, is, have, roundhouse, odp, parenthesis, was, be,
# Nearest to some: many, these, several, both, various, most, other, their,
# Nearest to years: days, months, times, year, weeks, hala, minutes, minute,
# Average loss at step 52000: 3.435723
# Average loss at step 54000: 3.428953
# Average loss at step 56000: 3.439919
# Average loss at step 58000: 3.400334
# Average loss at step 60000: 3.392782
# Nearest to into: through, from, within, doorman, around, juices, elegantly, legionnaire,
# Nearest to american: aleksei, australian, british, english, russian, french, german, italian,
# Nearest to an: glaciation, herbivore, unaids, concessions, coercion, the, sushi, honed,
# Nearest to his: her, their, its, my, the, our, your, deals,
# Nearest to can: may, could, will, would, must, might, cannot, should,
# Nearest to than: or, giordano, and, guild, afrika, certifications, disguising, deter,
# Nearest to will: would, can, may, could, must, might, should, shall,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to UNK: diamonds, youngsters, collapsing, leaded, trivial, luc, aq, undergoing,
# Nearest to time: manchus, seminar, period, way, year, loomis, beacon, money,
# Nearest to also: now, still, often, sometimes, actually, usually, then, which,
# Nearest to that: which, what, this, however, moshe, who, unfccc, it,
# Nearest to they: we, there, you, he, she, it, these, i,
# Nearest to are: were, is, have, odp, including, be, those, kroeber,
# Nearest to some: many, several, these, most, all, any, both, various,
# Nearest to years: days, months, times, year, weeks, minutes, minute, seconds,
# Average loss at step 62000: 3.247827
# Average loss at step 64000: 3.256362
# Average loss at step 66000: 3.406307
# Average loss at step 68000: 3.394871
# Average loss at step 70000: 3.363874
# Nearest to into: through, from, across, within, doorman, around, legionnaire, framed,
# Nearest to american: british, australian, aleksei, english, italian, french, russian, mexican,
# Nearest to an: glaciation, coercion, concessions, honed, the, herbivore, another, foreshadowing,
# Nearest to his: her, their, its, my, your, our, lifelong, stylized,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to than: or, guild, slightly, but, while, giordano, infibulation, floated,
# Nearest to will: would, can, could, may, must, should, might, shall,
# Nearest to three: six, four, seven, five, two, eight, nine, zero,
# Nearest to UNK: postscript, diverted, briand, abd, et, trivial, patagonian, undergoing,
# Nearest to time: year, manchus, period, peshawar, took, money, however, seminar,
# Nearest to also: now, still, sometimes, often, which, actually, locative, usually,
# Nearest to that: which, however, what, this, but, where, amygdala, crono,
# Nearest to they: we, he, there, you, it, she, who, then,
# Nearest to are: were, is, have, although, odp, include, while, including,
# Nearest to some: many, several, these, all, both, various, those, their,
# Nearest to years: days, months, year, minutes, weeks, times, decades, hours,
# Average loss at step 72000: 3.375875
# Average loss at step 74000: 3.347426
# Average loss at step 76000: 3.319097
# Average loss at step 78000: 3.357032
# Average loss at step 80000: 3.380750
# Nearest to into: through, from, within, across, legionnaire, around, elegantly, juices,
# Nearest to american: british, french, australian, aleksei, english, russian, italian, german,
# Nearest to an: glaciation, concessions, herbivore, another, foreshadowing, coercion, serb, unaids,
# Nearest to his: her, their, its, my, your, our, the, publicacion,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to than: or, slightly, but, abs, much, guild, kills, infibulation,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to UNK: novelist, chemist, http, coach, physicist, thompson, riefenstahl, lafayette,
# Nearest to time: year, manchus, period, life, gallbladder, took, disable, seminar,
# Nearest to also: still, often, sometimes, now, which, actually, ncbi, panhandle,
# Nearest to that: which, however, what, fluctuate, moshe, specimens, this, where,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to are: were, have, include, is, although, aperture, roundhouse, including,
# Nearest to some: many, several, various, certain, these, both, any, most,
# Nearest to years: days, months, weeks, times, minutes, year, decades, hours,
# Average loss at step 82000: 3.406822
# Average loss at step 84000: 3.412325
# Average loss at step 86000: 3.390671
# Average loss at step 88000: 3.355339
# Average loss at step 90000: 3.364268
# Nearest to into: through, from, around, across, legionnaire, within, doorman, elegantly,
# Nearest to american: british, french, australian, italian, english, actors, russian, aleksei,
# Nearest to an: another, honed, glaciation, lawrencium, herbivore, coercion, concessions, jackals,
# Nearest to his: her, their, its, my, your, our, the, whose,
# Nearest to can: could, may, must, will, would, should, might, cannot,
# Nearest to than: or, slightly, giordano, dist, even, no, abs, guild,
# Nearest to will: would, could, must, can, may, might, should, cannot,
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to UNK: barking, jones, sikhism, frigate, riefenstahl, bartholomew, csd, encyclopaedia,
# Nearest to time: year, took, period, mujahidin, disable, vinyl, day, place,
# Nearest to also: often, still, now, which, sometimes, actually, usually, never,
# Nearest to that: which, however, what, moshe, revamp, intersected, how, fluctuate,
# Nearest to they: we, he, you, there, she, it, not, who,
# Nearest to are: were, is, include, these, have, including, although, those,
# Nearest to some: many, several, these, any, both, all, various, most,
# Nearest to years: days, months, weeks, decades, minutes, hours, times, year,
# Average loss at step 92000: 3.398342
# Average loss at step 94000: 3.256187
# Average loss at step 96000: 3.360843
# Average loss at step 98000: 3.245322
# Average loss at step 100000: 3.355789
# Nearest to into: through, from, within, across, around, legionnaire, off, with,
# Nearest to american: british, australian, aleksei, italian, actors, english, russian, french,
# Nearest to an: glaciation, another, coercion, herbivore, foreshadowing, concessions, kinks, situated,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to can: could, may, must, will, should, would, might, cannot,
# Nearest to than: or, slightly, giordano, much, and, even, abs, infibulation,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to three: four, five, six, eight, two, seven, nine, zero,
# Nearest to UNK: referencing, mtp, anise, tartu, richelieu, briand, rossi, rence,
# Nearest to time: year, life, took, vinyl, seminar, period, boehm, day,
# Nearest to also: still, sometimes, now, often, actually, never, usually, ncbi,
# Nearest to that: which, however, what, ensues, but, nextstep, vilna, intersected,
# Nearest to they: we, he, there, you, she, it, i, not,
# Nearest to are: were, have, although, these, those, while, including, roundhouse,
# Nearest to some: many, several, these, any, all, certain, their, various,
# Nearest to years: days, months, weeks, decades, year, times, hours, minutes,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
